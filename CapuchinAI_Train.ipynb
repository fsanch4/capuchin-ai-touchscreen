# %% [markdown]
# # CapuchinAI Model Training
#
# This notebook uses YOLOv5 to train an individual recognition model. We use the [Multiple Capuchins](https://universe.roboflow.com/capuchin/multiple-capuchins/dataset/1/download/yolov5pytorch$0) dataset; this can easily be substituted with another suitable dataset.

# %% [markdown]
# 1. Change the hardware accelerator to GPU by going to `Runtime > Change runtime type`. We used the "T4 GPU" accelerator.
# 2. Install Roboflow (can ignore if using your own dataset).

# %%
# %pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 76.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# ...

# %% [markdown]
# 3. Download and set up YOLOv5.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 18370, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 18370 (delta 36), reused 17 (delta 17), pack-reused 18315 (from 3)
# Receiving objects: 100% (18370/18370), 17.47 MiB | 21.82 MiB/s, done.
# Resolving deltas: 100% (12481/12481), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.6/796.6 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.5 MB/s eta 0:00:00

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-505-gf4afe0f5 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.4/112.6 GB disk)

# %% [markdown]
# 4.  Download/upload a dataset.
#   - **If you want to use your own dataset:** upload it, formatted for YOLOv5, to the `Files` sidebar in the `/content/yolov5` directory (this is often the default open directory in the sidebar). Then uncomment and complete the code cell below. *Ignore the cell following that*.
#   - **If you want to use the Multiple Capuchins dataset:** continue running cells one by one.

# %%
# UNCOMMENT ONLY IF USING YOUR OWN DATASET
# location = /content/yolov5/[name of directory] # DO NOT include a / at the end

# %%
# Ignore this cell if using your own dataset
from roboflow import Roboflow
rf = Roboflow(api_key="d8fxdRQVyi36Dmh1wNWC")  # 🔁 replace with your actual API key
project = rf.workspace("capuchin").project("multiple-capuchins")
dataset = project.version(1).download("yolov5")
location = dataset.location
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Multiple-Capuchins-1 in yolov5pytorch:: 100%|██████████| 4332/4332 [00:00<00:00, 5063.34it/s]

# %% [markdown]
# 5. Train the model. This can take a while depending on the size of your dataset. For the Multiple Capuchins dataset this took around 30 minutes.

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {location}/data.yaml --weights yolov5n.pt --name capuchin_yolov5n
# Out:
# Streaming output truncated to the last 5000 lines.
#       30/49      1.03G    0.02516   0.005227    0.01044         33        416:  57% 69/122 [00:25<00:21,  2.52it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       30/49      1.03G    0.02516   0.005226    0.01044         25        416:  57% 70/122 [00:25<00:17,  2.89it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       30/49      1.03G    0.02515   0.005209    0.01044         18        416:  58% 71/122 [00:26<00:19,  2.56it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %% [markdown]
# 6. Download the trained model weights: the weights can be found in the `Files` sidebar at `/content/yolov5/runs/train/capuchin_yolov5n/weights/best.pt`
